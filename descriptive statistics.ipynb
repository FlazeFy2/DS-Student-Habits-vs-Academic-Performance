# %%
import pandas as pd
import statistics
import numpy as np

# Declaration
data = pd.read_csv("student_habits_performance.csv")

target_col = ['age','study_hours_per_day','social_media_hours','netflix_hours','attendance_percentage','sleep_hours','exercise_frequency','mental_health_rating','exam_score']

for dt in target_col:
    # Convert to int
    data[dt] = pd.to_numeric(data[dt], errors='coerce')
    
    # Remove NaN
    data = data.dropna(subset=[dt])

    max_val = data[dt].max()
    min_val = data[dt].min()
    range_val = max_val - min_val
    mean = round(data[dt].mean(),2)
    mode = round(statistics.mode(data[dt]),2)
    var = round(np.nanvar(data[dt],ddof=1),2)
    std = round(var ** 0.5,2)

    print(f"Max of {dt.title()} : {max_val}")
    print(f"Min of {dt.title()} : {min_val}")
    print(f"Range of {dt.title()} : {range_val}")
    print(f"Mean of {dt.title()} : {mean}")
    print(f"Mode of {dt.title()} : {mode}")
    print(f"Variance of {dt.title()} : {var}")
    print(f"Standard Deviance of {dt.title()} : {std}\n")
# Out:
# Max of Age : 24
# Min of Age : 17
# Range of Age : 7
# Mean of Age : 20.5
# Mode of Age : 20
# Variance of Age : 5.33
# Standard Deviance of Age : 2.31
#
# Max of Study_Hours_Per_Day : 8.3
# Min of Study_Hours_Per_Day : 0.0
# Range of Study_Hours_Per_Day : 8.3
# Mean of Study_Hours_Per_Day : 3.55
# Mode of Study_Hours_Per_Day : 3.5
# Variance of Study_Hours_Per_Day : 2.16
# Standard Deviance of Study_Hours_Per_Day : 1.47
#
# Max of Social_Media_Hours : 7.2
# Min of Social_Media_Hours : 0.0
# Range of Social_Media_Hours : 7.2
# Mean of Social_Media_Hours : 2.51
# Mode of Social_Media_Hours : 3.1
# Variance of Social_Media_Hours : 1.37
# Standard Deviance of Social_Media_Hours : 1.17
#
# Max of Netflix_Hours : 5.4
# Min of Netflix_Hours : 0.0
# Range of Netflix_Hours : 5.4
# Mean of Netflix_Hours : 1.82
# Mode of Netflix_Hours : 0.0
# Variance of Netflix_Hours : 1.16
# Standard Deviance of Netflix_Hours : 1.08
#
# Max of Attendance_Percentage : 100.0
# Min of Attendance_Percentage : 56.0
# Range of Attendance_Percentage : 44.0
# Mean of Attendance_Percentage : 84.13
# Mode of Attendance_Percentage : 100.0
# Variance of Attendance_Percentage : 88.35
# Standard Deviance of Attendance_Percentage : 9.4
#
# Max of Sleep_Hours : 10.0
# Min of Sleep_Hours : 3.2
# Range of Sleep_Hours : 6.8
# Mean of Sleep_Hours : 6.47
# Mode of Sleep_Hours : 6.5
# Variance of Sleep_Hours : 1.5
# Standard Deviance of Sleep_Hours : 1.22
#
# Max of Exercise_Frequency : 6
# Min of Exercise_Frequency : 0
# Range of Exercise_Frequency : 6
# Mean of Exercise_Frequency : 3.04
# Mode of Exercise_Frequency : 3
# Variance of Exercise_Frequency : 4.1
# Standard Deviance of Exercise_Frequency : 2.02
#
# Max of Mental_Health_Rating : 10
# Min of Mental_Health_Rating : 1
# Range of Mental_Health_Rating : 9
# Mean of Mental_Health_Rating : 5.44
# Mode of Mental_Health_Rating : 4
# Variance of Mental_Health_Rating : 8.11
# Standard Deviance of Mental_Health_Rating : 2.85
#
# Max of Exam_Score : 100.0
# Min of Exam_Score : 18.4
# Range of Exam_Score : 81.6
# Mean of Exam_Score : 69.6
# Mode of Exam_Score : 100.0
# Variance of Exam_Score : 285.22
# Standard Deviance of Exam_Score : 16.89
